# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import scrapy
from selenium import webdriver

# %%
# https://medium.com/analytics-vidhya/counter-strike-matches-result-prediction-537f8648ee7f

# %%
driver=webdriver.Chrome()

# %%
page = 0

# while page <= 99:

# %%
driver.get('https://www.hltv.org/results?offset='+str(page))

# %%
content=driver.page_source

# %%
content
# Out:
# '<html lang="en" data-client-country-iso="dk"><head><style>#asdasda {}</style>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1" id="metaViewport">\n    <meta property="fb:admins" content="1004164229">\n    <meta property="fb:pages" content="249997999009">\n    <meta property="fb:app_id" content="1460388157605817">\n    <meta name="google-site-verification" content="DcypRFLQvgYQL5Acx7feoGWbblSsmKv6HpPI7mM_1uw">\n    <meta name="yandex-verification" content="00ed04feb3ede037">\n    <link rel="apple-touch-icon" sizes="180x180" href="/img/static/favicon/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="/img/static/favicon/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="/img/static/favicon/favicon-16x16.png">\n    <link rel="manifest" href="/img/static/favicon/manifest.json">\n    <link rel="mask-icon" href="/img/static/favicon/safari-pinned-tab.svg" color="#5bbad5">\n    <meta name="theme-color" content="#ffffff">\n    <link href="https://fonts.googleapis.com/css?family=Open+Sans:400,400i,700,700i|Oswald:700&amp;amp;subset=latin-ext" rel="stylesheet">\n    <link rel="stylesheet" href="/vendor/font-awesome-4.7.0/css/font-awesome.min.css" type="text/css">\n    <script type="text/javascript" charset="UTF-8" async="" src="https://consent.cookiebot.com/e33407d2-0296-4168-a6fb-6e38ce5f1ffb/cc.js?renew=false&amp;referer=www.hltv.org&amp;dnt=false&amp;forceshow=false&amp;cbid=e33407d2-0296-4168-a6fb-6e38ce5f1ffb&amp;whitelabel=false&amp;brandid=Cookiebot&amp;framework=IABv2"></script><script type="text/javascript" charset="UTF-8" src="https://consent.cookiebot.com/Framework/IAB/consent-sdk-2.0.js"></script><script type="text/javascript" charset="UTF-8" src="https://consentcdn.cookiebot.com/consentconfig/e33407d2-0296-4168-a6fb-6e38ce5f1ffb/hltv.org/configuration.js"></script><script async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" src="/scripts/hltv-csstheme.js?hash=11d9be236eb7b28dba47b4184aa3b1cc" data-day-css="3dd234682c1b32f1c634a5ee2fe182a9" data-night-css="0e518b6b1cbb25eb081c11f30fd46c01"></script><link rel="stylesheet" href="/css/EverythingDay.css?hash=3dd234682c1b32f1c634a5ee2fe182a9" type="text/css" id="themeCssLink" data-day-css="/css/EverythingDay.css?hash=3dd234682c1b32f1c634a5ee2fe182a9" data-night-css="/css/EverythingNight.css?hash=0e518b6b1cbb25eb081c11f30fd46c01">\n\n    <script type="text/javascript" src="/scripts/hltv.js?hash=58be8249cd367191d641e73579ebd912"></script>\n    <script type="text/javascript" src="https://notification-secure.hltv.org/hltvNotification.js?v4" async="async"></script>\n    <script type="text/javascript" src="https://scorebot-secure.hltv.org/scorebotClientApi.js?v9" async="async"></script>\n    <title>CS:GO Results | HLTV.org</title>\n    <link href="/rss/news" rel="alternate" type="application/rss+xml">\n    <meta name="description" content="Match results from all competitive CS:GO Matches and events listed in one place.">\n    <meta property="og:title" content="HLTV.org - The home of competitive Counter-Strike">\n    <meta property="og:image" content="https://www.hltv.org/img/static/openGraphHltvLogo.png">\n    <meta property="og:site_name" content="HLTV.org">\n    <link href="https://www.hltv.org/results" rel="canonical">\n    <script type="text/javascript" src="https://consent.cookiebot.com/uc.js" id="Cookiebot" data-cbid="e33407d2-0296-4168-a6fb-6e38ce5f1ffb" data-blockingmode="auto" data-framework="IAB1"></script>\n    <script type="text/plain" src="https://hb.vntsm.com/v3/live/ad-manager.min.js" data-site-id="5e79f53e963d0e25e62b5f4f" data-mode="scan" async="async" data-cookieconsent="statistics,marketing"></script>\n  <script type="text/javascript" id="something11" src="https://intersc.igaming-service.io/hltv.org.js?ver=2020-10-26"></script><style type="text/css" id="CookieConsentStateDisplayStyles">.cookieconsent-optin-pref ...
